# %%
import os
import pandas as pd
import gmaps
import googlemaps as g
import yaml
import numpy
import matplotlib.pyplot as plt
from IPython.display import Image
import foursquare
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn import linear_model


# %matplotlib inline
plt.style.use('ggplot')

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 20)
pd.set_option('display.notebook_repr_html', True)

# Loading dataset
df = pd.read_csv(os.path.join('..', 'datasets', 'foursquare_idmapping.csv'))
# df = df.set_index(id)
df.drop(['Unnamed: 0'],inplace = True, axis = 1)
df.head()
len(df)
# Out:
# 5568

# %%
# Applying foursquare credentials
with open('foursquare.yaml', 'r') as f:
    fs_credentials = yaml.load(f)

fs_client_id = fs_credentials['client-id']
fs_client_secret = fs_credentials['client-secret']

# %%
client = foursquare.Foursquare(client_id=fs_client_id, client_secret=fs_client_secret)

# %%
# df.dropna(subset = ['foursquare_id'], inplace = True)
len(df)
# Out:
# 5568

# %%
def foursquare_attributes(id):
    restaurant = client.venues(id)
    if restaurant['venue']:
        r = restaurant['venue']       
        return {
            'foursquare_id': id,
            'price': r.get('price', {}).get('tier'),
            'hasMenu': r.get('hasMenu') != None,
            'rating': r.get('rating'),
            'ratingSignals': r.get('ratingSignals'), 
            'photos': r.get('photos').get('count'),
#             'hasReservations': r.get('attributes').get('groups').'type'.'reservations'.get('displayValue') != None,
            'tipCount': r.get('stats').get('tipCount'),
#              'hasOutdoorSeating': r.get('attributes').get('groups')[2].get('items')[1] != None,
            'checkinsCount': r.get('stats').get('checkinsCount')
        }
    
r = foursquare_attributes(df.foursquare_id[0])
# print attributes

# %%
{}.get('a')

# %%
foursquare_rows = [
    foursquare_attributes(df.foursquare_id[i]) 
    for i in range(0, len(df)) if not(pd.isnull(df.foursquare_id[i]))
]
# foursquare_rows

# %%
foursquare_df = pd.DataFrame(foursquare_rows)
foursquare_df
# Out:
#     checkinsCount             foursquare_id  hasMenu  photos  price  rating  \
# 0            1490  4ae289b9f964a520e78e21e3     True      79    3.0     6.3
# 1             149  4c1a7695eac020a1105043c2    False       1    1.0     NaN
# 2             798  4bb7d9273db7b71353aa209a     True      53    1.0     8.9
# 3             916  4ab90c8bf964a520d27d20e3    False      41    1.0     7.4
# 4            3775  3fd66200f964a52019f11ee3     True     167    1.0     8.8
# 5            3116  4c1f9a12b306c92885ad68b7     True     133    3.0     8.2
# 6             113  4dbcbee46e810768bf678f0f    False       0    NaN     NaN
# 7            2313  44d756a9f964a52068361fe3    False      62    1.0     6.1
# 8            7425  4a6f5d0ef964a520fdd51fe3     True      92    1.0     8.9
# 9            3416  4aff1091f964a520b53322e3     True     350    1.0     7.2
# ..            ...                       ...      ...     ...    ...     ...
# 84             18  4c015f94f7ab0f4758fd15b6    False       3    NaN     NaN
# 85            886  4b140774f964a5200c9c23e3    False       3    2.0     7.9
# 86           1070  4b3d2bc9f964a520808f25e3     True      34    1.0     7.1
# 87          49635  49d2c3b6f964a520d15b1fe3     True    1382    NaN     8.0
# 88             34  4cc0591ca0c4f04d5f3d5a31    False       1    NaN     NaN
# 89          49635  49d2c3b6f964a520d15b1fe3     True    1382    NaN     8.0
# 90            200  4aeb443bf964a52057c021e3    False       6    NaN     8.0
# 91            693  4ac7cb2af964a520ccb920e3    False      65    1.0     6.6
# 92           1448  4a0083c8f964a5208a701fe3     True      15    1.0     6.8
# 93          21160  42e03700f964a52065261fe3     True    1517    4.0     9.2
#
#     ratingSignals  tipCount
# 0            56.0        18
# 1             NaN         1
# 2            71.0        24
# 3            33.0        10
# 4           190.0        82
# 5           195.0        72
# 6             NaN         0
# 7            71.0        30
# 8           353.0        83
# 9           141.0        41
# ..            ...       ...
# 84            NaN         0
# 85           21.0        10
# 86           17.0        11
# 87          822.0       149
# 88            NaN         0
# 89          822.0       149
# 90           10.0         1
# 91           23.0         7
# 92           50.0        19
# 93         1008.0       278
#
# [94 rows x 8 columns]

# %%
# df.join(foursquare_df, on='foursquare_id', lsuffix='l_', rsuffix='r_')
df2 = df.merge(foursquare_df, on='foursquare_id')
df2
# Out:
#                      business_name                  location  \
# 0                 Tiramisu Kitchen  (37.791116, -122.403816)
# 1            Nrgize Lifestyle Cafe  (37.786848, -122.421547)
# 2   Norman's Ice Cream and Freezes  (37.807155, -122.419004)
# 3              CHARLIE'S DELI CAFE  (37.747114, -122.413641)
# 4                       ART'S CAFE  (37.764013, -122.465749)
# 5                       SUSHI ZONE  (37.771437, -122.423892)
# 6              RHODA GOLDMAN PLAZA  (37.784626, -122.437734)
# 7                       CAFE X + O  (37.742325, -122.426476)
# 8                      Oasis Grill  (37.794483, -122.396584)
# 9                         Chowders   (37.80824, -122.410189)
# ..                             ...                       ...
# 88           SUPER STAR RESTAURANT  (37.719692, -122.438575)
# 89    SF MARRIOTT HOTEL PANTRY 5/F  (37.784964, -122.404752)
# 90    SF MARRIOTT HOTEL PANTRY 5/F  (37.784964, -122.404752)
# 91  SF MARRIOTT VIEW LOUNGE PANTRY  (37.784964, -122.404752)
# 92  SF MARRIOTT VIEW LOUNGE PANTRY  (37.784964, -122.404752)
# 93    SF MARRIOTT HOTEL PANTRY 4/F  (37.784964, -122.404752)
# 94             COW HOLLOW CATERING  (37.801401, -122.447857)
# 95                HAAGEN-DAZS #561  (37.784317, -122.407563)
# 96                         EL FARO  (37.788613, -122.393894)
# 97                  HOUSE OF HUNAN  (37.757923, -122.393914)
#
#     inspection_score             foursquare_id  \
# 0          87.400000  4ae289b9f964a520e78e21e3
# 1          94.000000  4c1a7695eac020a1105043c2
# 2          87.750000  4bb7d9273db7b71353aa209a
# 3          83.200000  4ab90c8bf964a520d27d20e3
# 4          92.500000  3fd66200f964a52019f11ee3
# 5          82.500000  4c1f9a12b306c92885ad68b7
# 6          94.666667  4dbcbee46e810768bf678f0f
# 7          91.333333  44d756a9f964a52068361fe3
# 8          75.000000  4a6f5d0ef964a520fdd51fe3
# 9          93.333333  4aff1091f964a520b53322e3
# ..               ...                       ...
# 88         87.666667  4b3d2bc9f964a520808f25e3
# 89         98.000000  49d2c3b6f964a520d15b1fe3
# 90         98.000000  49d2c3b6f964a520d15b1fe3
# 91         96.000000  49d2c3b6f964a520d15b1fe3
# 92         96.000000  49d2c3b6f964a520d15b1fe3
# 93         97.600000  4cc0591ca0c4f04d5f3d5a31
# 94         96.000000  4aeb443bf964a52057c021e3
# 95         82.066667  4ac7cb2af964a520ccb920e3
# 96         98.000000  4a0083c8f964a5208a701fe3
# 97         81.857143  42e03700f964a52065261fe3
#
#                           foursquare_name  checkinsCount  hasMenu  photos  \
# 0                           Cafe Tiramisu           1490     True      79
# 1                   Nrgize Lifestyle Cafe            149    False       1
# 2            Norman's Ice Cream & Freezes            798     True      53
# 3                     Charlie's Deli Cafe            916    False      41
# 4                              Art's Cafe           3775     True     167
# 5                              Sushi Zone           3116     True     133
# 6                     Rhoda Goldman Plaza            113    False       0
# 7                                 Cafe XO           2313    False      62
# 8                             Oasis Grill           7425     True      92
# 9                                Chowders           3416     True     350
# ..                                    ...            ...      ...     ...
# 88                  Super Star Restaurant           1070     True      34
# 89         San Francisco Marriott Marquis          49635     True    1382
# 90         San Francisco Marriott Marquis          49635     True    1382
# 91         San Francisco Marriott Marquis          49635     True    1382
# 92         San Francisco Marriott Marquis          49635     True    1382
# 93  Marriott Hotel 4TH Floor Meeting Room             34    False       1
# 94      Cow Hollow Playground & Clubhouse            200    False       6
# 95                            Häagen-Dazs            693    False      65
# 96                                El Faro           1448     True      15
# 97                     House of Prime Rib          21160     True    1517
#
#     price  rating  ratingSignals  tipCount
# 0     3.0     6.3           56.0        18
# 1     1.0     NaN            NaN         1
# 2     1.0     8.9           71.0        24
# 3     1.0     7.4           33.0        10
# 4     1.0     8.8          190.0        82
# 5     3.0     8.2          195.0        72
# 6     NaN     NaN            NaN         0
# 7     1.0     6.1           71.0        30
# 8     1.0     8.9          353.0        83
# 9     1.0     7.2          141.0        41
# ..    ...     ...            ...       ...
# 88    1.0     7.1           17.0        11
# 89    NaN     8.0          822.0       149
# 90    NaN     8.0          822.0       149
# 91    NaN     8.0          822.0       149
# 92    NaN     8.0          822.0       149
# 93    NaN     NaN            NaN         0
# 94    NaN     8.0           10.0         1
# 95    1.0     6.6           23.0         7
# 96    1.0     6.8           50.0        19
# 97    4.0     9.2         1008.0       278
#
# [98 rows x 12 columns]

# %%
df2.count(axis=0, level=None, numeric_only=False)
# Out:
# business_name       98
# location            98
# inspection_score    98
# foursquare_id       98
# foursquare_name     98
# checkinsCount       98
# hasMenu             98
# photos              98
# price               79
# rating              79
# ratingSignals       79
# tipCount            98
# dtype: int64

# %%
len(df)
# Out:
# 5568

# %%
# Splitting the dataframe into test and train 
df_train, df_test = train_test_split(df2,test_size=0.4, random_state=42)

# %%
len(df_train)
# Out:
# 58
