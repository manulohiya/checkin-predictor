# %%
import os
import pandas as pd
import gmaps
import googlemaps as g
import yaml
import numpy
import matplotlib.pyplot as plt
from IPython.display import Image
import foursquare
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn import linear_model


# %matplotlib inline
plt.style.use('ggplot')

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 20)
pd.set_option('display.notebook_repr_html', True)

# Loading dataset
df = pd.read_csv(os.path.join('..', 'datasets', 'foursquare_idmapping.csv'))
# df = df.set_index(id)
df.drop(['Unnamed: 0'],inplace = True, axis = 1)
df.drop(['business_name'],inplace = True, axis = 1)
df.drop(['location'],inplace = True, axis = 1)
df.head()
# Out:
#    inspection_score             foursquare_id               foursquare_name
# 0         87.400000  4ae289b9f964a520e78e21e3                 Cafe Tiramisu
# 1         94.000000  4c1a7695eac020a1105043c2         Nrgize Lifestyle Cafe
# 2         96.333333                       NaN                           NaN
# 3         87.750000  4bb7d9273db7b71353aa209a  Norman's Ice Cream & Freezes
# 4         83.200000  4ab90c8bf964a520d27d20e3           Charlie's Deli Cafe

# %%
grouped_df = df.groupby(['foursquare_id','foursquare_name'], as_index = False)['inspection_score'].mean()
grouped_df.head()
# Out:
#               foursquare_id         foursquare_name  inspection_score
# 0  3fd66200f964a52001ed1ee3            Pacific Cafe         86.000000
# 1  3fd66200f964a52005ed1ee3  Taiwan Restaurant 台灣飯店         74.111111
# 2  3fd66200f964a52006ed1ee3   Tanuki Restaurant 狸壽司         92.000000
# 3  3fd66200f964a52013ed1ee3              Acquerello         98.666667
# 4  3fd66200f964a52017ed1ee3                   Ebisu         80.000000

# %%
# Applying foursquare credentials
with open('foursquare.yaml', 'r') as f:
    fs_credentials = yaml.load(f)

fs_client_id = fs_credentials['client-id']
fs_client_secret = fs_credentials['client-secret']

# %%
client = foursquare.Foursquare(client_id=fs_client_id, client_secret=fs_client_secret)

# %%
# df.dropna(subset = ['foursquare_id'], inplace = True)
len(grouped_df)
# Out:
# 4482

# %%
def foursquare_attributes(id):
    restaurant = client.venues(id)
    if restaurant['venue']:
        r = restaurant['venue']       
        return {
            'foursquare_id': id,
            'price': r.get('price', {}).get('tier'),
            'hasMenu': r.get('hasMenu') != None,
            'rating': r.get('rating'),
            'ratingSignals': r.get('ratingSignals'), 
            'photos': r.get('photos').get('count'),
            'isVerified': r.get('verified') != None,
#             'hasReservations': r.get('attributes').get('groups').'type'.'reservations'.get('displayValue') != None,
            'tipCount': r.get('stats').get('tipCount'),
#              'hasOutdoorSeating': r.get('attributes').get('groups')[2].get('items')[1] != None,
            'createdAt': r.get('createdAt'),
            'checkinsCount': r.get('stats').get('checkinsCount')
           
        }
    
r = foursquare_attributes(df.foursquare_id[0])
# print attributes

# %%
{}.get('a')
grouped_df.head()
# Out:
#               foursquare_id         foursquare_name  inspection_score
# 0  3fd66200f964a52001ed1ee3            Pacific Cafe         86.000000
# 1  3fd66200f964a52005ed1ee3  Taiwan Restaurant 台灣飯店         74.111111
# 2  3fd66200f964a52006ed1ee3   Tanuki Restaurant 狸壽司         92.000000
# 3  3fd66200f964a52013ed1ee3              Acquerello         98.666667
# 4  3fd66200f964a52017ed1ee3                   Ebisu         80.000000

# %%
foursquare_rows = [
    foursquare_attributes(grouped_df.foursquare_id[i]) 
    for i in range(0, len(grouped_df)) if not(pd.isnull(grouped_df.foursquare_id[i]))
]
# foursquare_rows

# %%
foursquare_df = pd.DataFrame(foursquare_rows)
foursquare_df
# Out:
#       checkinsCount   createdAt             foursquare_id  hasMenu  \
# 0              1389  1071014400  3fd66200f964a52001ed1ee3     True
# 1              2173  1071014400  3fd66200f964a52005ed1ee3     True
# 2              1149  1071014400  3fd66200f964a52006ed1ee3     True
# 3              1185  1071014400  3fd66200f964a52013ed1ee3     True
# 4              5047  1071014400  3fd66200f964a52017ed1ee3     True
# 5              2275  1071014400  3fd66200f964a52018f11ee3    False
# 6              3775  1071014400  3fd66200f964a52019f11ee3     True
# 7              6945  1071014400  3fd66200f964a5201af11ee3     True
# 8              2067  1071014400  3fd66200f964a5201bed1ee3     True
# 9              3646  1071014400  3fd66200f964a52021ed1ee3     True
# ...             ...         ...                       ...      ...
# 4472             15  1497492583  5941ec67e2ead1688f4f464a    False
# 4473             30  1497640045  59442c6d3149b909cb3dd44e    False
# 4474            293  1497729609  59458a49625a66644499c8bf    False
# 4475              2  1498616777  595313c9c21cb164ba5e938e    False
# 4476             35  1499414850  595f4142e2da196c104bc488    False
# 4477              1  1501098470  5978f1e67dc9e13859f985af    False
# 4478              1  1501436242  597e1952270ee719139b65b0    False
# 4479              2  1501869287  5984b4e77918717aa95cb95e    False
# 4480              1  1502145517  5988ebed1499463427da52e6    False
# 4481              0  1503523209  599df189e185f30168288183    False
#
#       isVerified  photos  price  rating  ratingSignals  tipCount
# 0           True      78    2.0     8.1           59.0        24
# 1           True     185    1.0     7.2           37.0        12
# 2           True      46    2.0     7.9           34.0        13
# 3           True      72    4.0     8.5          108.0        41
# 4           True     254    3.0     9.4          307.0        88
# 5           True     103    2.0     7.5           78.0        20
# 6           True     167    1.0     8.8          190.0        82
# 7           True     193    2.0     8.1          271.0       108
# 8           True      76    3.0     7.7           93.0        23
# 9           True     150    2.0     8.1          152.0        46
# ...          ...     ...    ...     ...            ...       ...
# 4472        True       0    1.0     NaN            NaN         0
# 4473        True       2    1.0     NaN            NaN         0
# 4474        True      27    1.0     7.0           48.0         8
# 4475        True       0    1.0     NaN            NaN         0
# 4476        True       0    3.0     NaN            NaN         0
# 4477        True       0    1.0     NaN            NaN         0
# 4478        True       0    NaN     NaN            NaN         0
# 4479        True       1    NaN     NaN            NaN         0
# 4480        True       0    NaN     NaN            NaN         0
# 4481        True       0    1.0     NaN            NaN         0
#
# [4482 rows x 10 columns]

# %%
# df.join(foursquare_df, on='foursquare_id', lsuffix='l_', rsuffix='r_')
df2 = grouped_df.merge(foursquare_df, on='foursquare_id')
df2
# Out:
#                  foursquare_id                            foursquare_name  \
# 0     3fd66200f964a52001ed1ee3                               Pacific Cafe
# 1     3fd66200f964a52005ed1ee3                     Taiwan Restaurant 台灣飯店
# 2     3fd66200f964a52006ed1ee3                      Tanuki Restaurant 狸壽司
# 3     3fd66200f964a52013ed1ee3                                 Acquerello
# 4     3fd66200f964a52017ed1ee3                                      Ebisu
# 5     3fd66200f964a52018f11ee3                              Durty Nelly's
# 6     3fd66200f964a52019f11ee3                                 Art's Cafe
# 7     3fd66200f964a5201af11ee3                            Grubstake Diner
# 8     3fd66200f964a5201bed1ee3                                   Fringale
# 9     3fd66200f964a52021ed1ee3                                Marnee Thai
# ...                        ...                                        ...
# 4472  5941ec67e2ead1688f4f464a                          El Gran Taco Loco
# 4473  59442c6d3149b909cb3dd44e                     La Panotiq Bakery Cafe
# 4474  59458a49625a66644499c8bf                           Le Marais Bakery
# 4475  595313c9c21cb164ba5e938e  Humphry Slocombe Ice Cream @ Off The Grid
# 4476  595f4142e2da196c104bc488                                    Bar 587
# 4477  5978f1e67dc9e13859f985af                              Tacos El Tuca
# 4478  597e1952270ee719139b65b0                       Lakshmi Lassi & Chai
# 4479  5984b4e77918717aa95cb95e                                      BHLDN
# 4480  5988ebed1499463427da52e6                                RankScience
# 4481  599df189e185f30168288183                          Happy Moose Juice
#
#       inspection_score  checkinsCount   createdAt  hasMenu  isVerified  \
# 0            86.000000           1389  1071014400     True        True
# 1            74.111111           2173  1071014400     True        True
# 2            92.000000           1149  1071014400     True        True
# 3            98.666667           1185  1071014400     True        True
# 4            80.000000           5047  1071014400     True        True
# 5            93.111111           2275  1071014400    False        True
# 6            92.500000           3775  1071014400     True        True
# 7            98.000000           6945  1071014400     True        True
# 8            88.600000           2067  1071014400     True        True
# 9            81.397436           3646  1071014400     True        True
# ...                ...            ...         ...      ...         ...
# 4472         86.090909             15  1497492583    False        True
# 4473         95.000000             30  1497640045    False        True
# 4474         91.454545            293  1497729609    False        True
# 4475         94.000000              2  1498616777    False        True
# 4476        100.000000             35  1499414850    False        True
# 4477         88.333333              1  1501098470    False        True
# 4478        100.000000              1  1501436242    False        True
# 4479        100.000000              2  1501869287    False        True
# 4480         91.666667              1  1502145517    False        True
# 4481         96.666667              0  1503523209    False        True
#
#       photos  price  rating  ratingSignals  tipCount
# 0         78    2.0     8.1           59.0        24
# 1        185    1.0     7.2           37.0        12
# 2         46    2.0     7.9           34.0        13
# 3         72    4.0     8.5          108.0        41
# 4        254    3.0     9.4          307.0        88
# 5        103    2.0     7.5           78.0        20
# 6        167    1.0     8.8          190.0        82
# 7        193    2.0     8.1          271.0       108
# 8         76    3.0     7.7           93.0        23
# 9        150    2.0     8.1          152.0        46
# ...      ...    ...     ...            ...       ...
# 4472       0    1.0     NaN            NaN         0
# 4473       2    1.0     NaN            NaN         0
# 4474      27    1.0     7.0           48.0         8
# 4475       0    1.0     NaN            NaN         0
# 4476       0    3.0     NaN            NaN         0
# 4477       0    1.0     NaN            NaN         0
# 4478       0    NaN     NaN            NaN         0
# 4479       1    NaN     NaN            NaN         0
# 4480       0    NaN     NaN            NaN         0
# 4481       0    1.0     NaN            NaN         0
#
# [4482 rows x 12 columns]

# %%
df2.count(axis=0, level=None, numeric_only=False)
# Out:
# foursquare_id       4482
# foursquare_name     4482
# inspection_score    4482
# checkinsCount       4482
# createdAt           4482
# hasMenu             4482
# isVerified          4482
# photos              4482
# price               3362
# rating              3320
# ratingSignals       3320
# tipCount            4482
# dtype: int64

# %%
len(df2)
# Out:
# 4482

# %%
# Saving the foursquare id mapping to a csv for use for EDA and modeling

df2.to_csv(os.path.join('..','datasets','venue_attributes.csv'))
